# %%
from pathlib import Path
import pandas as pd

data_dir = Path("./mgat1ko_data/nav")
cm = pd.read_excel(data_dir/"capacitance.xlsx")

# %% [markdown]
# ## Normalize current traces by the cell capacitance

# %%
fpaths = (data_dir/"wt-trace").glob("*.xlsx")
fnames = [f.stem for f in fpaths]

for idx,row in cm[cm['group']=='WT'].iterrows():
    if str(row.file_name) in fnames:
        print(f"File {idx}: {row.file_name} is in file list")
    else:
        print(f"File {idx}: {row.file_name} is NOT in file list")
# Out:
# File 0: 18o18002 is in file list
# File 1: 18111002 is in file list
# File 2: 18111007 is in file list
# File 3: 18112001 is in file list
# File 4: 18116006 is in file list
# File 5: 18116011 is in file list
# File 6: 18116016 is in file list
# File 7: 18122004 is in file list
# File 8: 18122010 is in file list
# File 9: 18124001 is in file list
# File 10: 18124006 is in file list
# File 11: 18124011 is in file list
# File 12: 18124016 is in file list
# File 13: 18129001 is in file list
# File 14: 18129013 is in file list
# File 15: 18129018 is in file list
# File 16: 18201001 is in file list
# File 17: 18201009 is in file list
# File 18: 18201027 is in file list
# File 19: 18201031 is in file list
# File 20: 18713004 is in file list
# File 21: 18717001 is in file list
# File 22: 18717007 is in file list

# %%
fpaths = (data_dir/"mgat1ko-trace").glob("*.xlsx")
fnames = [f.stem for f in fpaths]

for idx,row in cm[cm['group']=='MGAT1KO'].iterrows():
    if str(row.file_name) in fnames:
        print(f"File {idx}: {row.file_name} is in file list")
    else:
        print(f"File {idx}: {row.file_name} is NOT in file list")
# Out:
# File 23: 18118001 is in file list
# File 24: 18118004 is in file list
# File 25: 18118009 is in file list
# File 26: 18118010 is in file list
# File 27: 18118015 is in file list
# File 28: 18119001 is in file list
# File 29: 18119006 is in file list
# File 30: 18123001 is in file list
# File 31: 18123006 is in file list
# File 32: 18123009 is in file list
# File 33: 18123012 is in file list
# File 34: 18126002 is in file list
# File 35: 18130001 is in file list
# File 36: 18130013 is in file list
# File 37: 18130018 is in file list
# File 38: 18131001 is in file list

# %%
save_dir = data_dir/"wt-trace-preprocessed"
save_dir.mkdir(parents=True, exist_ok=True)
for idx,row in cm[cm['group']=='WT'].iterrows():
    p = data_dir/"wt-trace"/(str(row.file_name)+".xlsx")
    ctrace = pd.read_excel(p)
    ctrace.iloc[:,1:] = ctrace.iloc[:,1:]/row.cm
    ctrace.to_csv(save_dir/(str(row.file_name)+".csv"), index=False);

# %% [markdown]
# ### Test the result

# %%
cm.iloc[13,:]
# Out:
# group              WT
# file_name    18129001
# cm                164
# Name: 13, dtype: object

# %%
ctrace = pd.read_excel(data_dir/"wt-trace"/(str(cm.file_name.iloc[13])+".xlsx"))
ctrace
# Out:
#         time(ms)  -85.00(Im)  -80.00(Im)  -75.00(Im)  -70.00(Im)  -65.00(Im)  \
# 0       0.000000 -149.536118 -131.225571  -97.656242 -125.122063 -112.915031
# 1       0.050000 -131.225571 -131.225571 -109.863274 -119.018547 -122.070305
# 2       0.100000 -143.432602 -125.122063 -119.018547 -125.122063 -137.329086
# 3       0.150000 -143.432602 -128.173813 -115.966789 -122.070305 -122.070305
# 4       0.200000 -109.863274 -131.225571 -131.225571 -131.225571 -125.122063
# ...          ...         ...         ...         ...         ...         ...
# 2995  149.750000 -158.691391 -180.053696 -122.070305 -167.846664 -161.743149
# 2996  149.800003 -170.898422 -195.312485 -131.225571 -170.898422 -170.898422
# 2997  149.850006 -161.743149 -195.312485 -134.277328 -177.001938 -170.898422
# 2998  149.899994 -143.432602 -183.105453 -131.225571 -170.898422 -170.898422
# 2999  149.949997 -146.484360 -183.105453 -140.380844 -158.691391 -170.898422
#
#       -60.00(Im)  -55.00(Im)  -50.00(Im)  -45.00(Im)  ...  -35.00(ImC)  \
# 0    -152.587875 -119.018547 -128.173813 -125.122063  ...    15.258788
# 1    -146.484360 -115.966789 -112.915031 -125.122063  ...    -3.051758
# 2    -143.432602 -122.070305 -119.018547 -128.173813  ...    33.569332
# 3    -128.173813 -112.915031 -137.329086 -122.070305  ...   -12.207030
# 4    -131.225571 -122.070305 -134.277328 -128.173813  ...    18.310545
# ...          ...         ...         ...         ...  ...          ...
# 2995 -170.898422 -170.898422 -207.519516 -222.778305  ...  -140.380844
# 2996 -158.691391 -183.105453 -195.312485 -219.726547  ...  -158.691391
# 2997 -164.794907 -177.001938 -201.416000 -219.726547  ...  -158.691391
# 2998 -183.105453 -180.053696 -210.571274 -222.778305  ...  -128.173813
# 2999 -164.794907 -189.208969 -195.312485 -225.830063  ...  -137.329086
#
#       -30.00(ImC)  -25.00(ImC)  -20.00(ImC)  -15.00(ImC)  -10.00(ImC)  \
# 0      -18.310545    30.517576    15.258788    12.207030   -36.621090
# 1        9.155272    15.258788     9.155272     3.051758   -27.465818
# 2        6.103515    39.672848    12.207030    36.621090    21.362303
# 3       51.879879    30.517576    18.310545    33.569332     6.103515
# 4        9.155272     9.155272    -6.103515    45.776363     0.000000
# ...           ...          ...          ...          ...          ...
# 2995  -186.157211  -195.312485  -204.467758  -231.933578  -210.571274
# 2996  -186.157211  -140.380844  -201.416000  -228.881821  -210.571274
# 2997  -219.726547  -125.122063  -247.192368  -231.933578  -207.519516
# 2998  -231.933578   -82.397453  -213.623032  -192.260727  -201.416000
# 2999  -204.467758  -115.966789  -219.726547  -213.623032  -228.881821
#
#       -5.00(ImC)   0.00(ImC)   5.00(ImC)  10.00(ImC)
# 0       0.000000   45.776363  -18.310545   18.310545
# 1      -3.051758   15.258788   -3.051758   -9.155272
# 2      12.207030  -18.310545    9.155272  -33.569332
# 3      -9.155272  -51.879879   27.465818  -21.362303
# 4      -6.103515  -42.724606    9.155272  -21.362303
# ...          ...         ...         ...         ...
# 2995 -283.813446 -228.881821 -268.554657  302.123993
# 2996 -289.916962 -259.399384 -265.502899  308.227509
# 2997 -265.502899 -247.192368 -286.865204  305.175751
# 2998 -241.088852 -228.881821 -274.658173  341.796844
# 2999 -253.295883 -238.037094 -268.554657  314.331024
#
# [3000 rows x 41 columns]

# %%
ctrace.iloc[:,1:] = ctrace.iloc[:,1:]/cm.cm.iloc[13]
ctrace
# Out:
#         time(ms)  -85.00(Im)  -80.00(Im)  -75.00(Im)  -70.00(Im)  -65.00(Im)  \
# 0       0.000000   -0.911806   -0.800156   -0.595465   -0.762939   -0.688506
# 1       0.050000   -0.800156   -0.800156   -0.669898   -0.725723   -0.744331
# 2       0.100000   -0.874589   -0.762939   -0.725723   -0.762939   -0.837372
# 3       0.150000   -0.874589   -0.781548   -0.707115   -0.744331   -0.744331
# 4       0.200000   -0.669898   -0.800156   -0.800156   -0.800156   -0.762939
# ...          ...         ...         ...         ...         ...         ...
# 2995  149.750000   -0.967630   -1.097888   -0.744331   -1.023455   -0.986239
# 2996  149.800003   -1.042064   -1.190930   -0.800156   -1.042064   -1.042064
# 2997  149.850006   -0.986239   -1.190930   -0.818764   -1.079280   -1.042064
# 2998  149.899994   -0.874589   -1.116497   -0.800156   -1.042064   -1.042064
# 2999  149.949997   -0.893197   -1.116497   -0.855981   -0.967630   -1.042064
#
#       -60.00(Im)  -55.00(Im)  -50.00(Im)  -45.00(Im)  ...  -35.00(ImC)  \
# 0      -0.930414   -0.725723   -0.781548   -0.762939  ...     0.093041
# 1      -0.893197   -0.707115   -0.688506   -0.762939  ...    -0.018608
# 2      -0.874589   -0.744331   -0.725723   -0.781548  ...     0.204691
# 3      -0.781548   -0.688506   -0.837372   -0.744331  ...    -0.074433
# 4      -0.800156   -0.744331   -0.818764   -0.781548  ...     0.111650
# ...          ...         ...         ...         ...  ...          ...
# 2995   -1.042064   -1.042064   -1.265363   -1.358404  ...    -0.855981
# 2996   -0.967630   -1.116497   -1.190930   -1.339796  ...    -0.967630
# 2997   -1.004847   -1.079280   -1.228146   -1.339796  ...    -0.967630
# 2998   -1.116497   -1.097888   -1.283971   -1.358404  ...    -0.781548
# 2999   -1.004847   -1.153713   -1.190930   -1.377013  ...    -0.837372
#
#       -30.00(ImC)  -25.00(ImC)  -20.00(ImC)  -15.00(ImC)  -10.00(ImC)  \
# 0       -0.111650     0.186083     0.093041     0.074433    -0.223299
# 1        0.055825     0.093041     0.055825     0.018608    -0.167475
# 2        0.037217     0.241908     0.074433     0.223299     0.130258
# 3        0.316341     0.186083     0.111650     0.204691     0.037217
# 4        0.055825     0.055825    -0.037217     0.279124     0.000000
# ...           ...          ...          ...          ...          ...
# 2995    -1.135105    -1.190930    -1.246755    -1.414229    -1.283971
# 2996    -1.135105    -0.855981    -1.228146    -1.395621    -1.283971
# 2997    -1.339796    -0.762939    -1.507271    -1.414229    -1.265363
# 2998    -1.414229    -0.502423    -1.302579    -1.172322    -1.228146
# 2999    -1.246755    -0.707115    -1.339796    -1.302579    -1.395621
#
#       -5.00(ImC)  0.00(ImC)  5.00(ImC)  10.00(ImC)
# 0       0.000000   0.279124  -0.111650    0.111650
# 1      -0.018608   0.093041  -0.018608   -0.055825
# 2       0.074433  -0.111650   0.055825   -0.204691
# 3      -0.055825  -0.316341   0.167475   -0.130258
# 4      -0.037217  -0.260516   0.055825   -0.130258
# ...          ...        ...        ...         ...
# 2995   -1.730570  -1.395621  -1.637528    1.842219
# 2996   -1.767786  -1.581704  -1.618920    1.879436
# 2997   -1.618920  -1.507271  -1.749178    1.860828
# 2998   -1.470054  -1.395621  -1.674745    2.084127
# 2999   -1.544487  -1.451446  -1.637528    1.916653
#
# [3000 rows x 41 columns]

# %%
save_dir = data_dir/"mgat1ko-trace-preprocessed"
save_dir.mkdir(parents=True, exist_ok=True)
for idx,row in cm[cm['group']=='MGAT1KO'].iterrows():
    p = data_dir/"mgat1ko-trace"/(str(row.file_name)+".xlsx")
    ctrace = pd.read_excel(p)
    ctrace.iloc[:,1:] = ctrace.iloc[:,1:]/row.cm
    ctrace.to_csv(save_dir/(str(row.file_name)+".csv"), index=False);
